# %% [markdown]
# <a href="https://colab.research.google.com/github/Anyugucaleb001/DTS-works/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment Questions the (#) is representing the question type/question.


# 1.creat a list of 5 students

score = [10,20,30,40,50]
print(score)

# %%
# compute the average score
average = sum(score)/len(score)
print(average)

# %%
#find the highest score
highest_score = max(score)
print(highest_score)

# %%
# creat a dictionary with 5 students with their score
students = {'caleb':92,'damian':69,'paul':75,'judge':70,'john':80}
print(students)

# %%
# find the highest scoring student
highest_scoring_student = max(students,key=students.get)
print(highest_scoring_student)

# %%
# creat a turple of subjects
subjects = ('maths','statistic','English','physics','Government')
print(subjects)

# %%
# creat a set of unique scores
unique_scores = set(score)
print(unique_scores)

# %% [markdown]
# The above codes is for the week three assignment.
#
# Name: Anyugu caleb Aondongu.
#
# mat num: un/2025/cp/0155
#
# Det: DATA SCIENCE
#
# fact: computing
